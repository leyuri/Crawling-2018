# %%
import json
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('KPOP2013.csv', encoding = 'UTF8')

# %%
df
# Out:
#                                 fullname  \
# 0                          13년 다 죽여  👑 💙
# 1                                    ali
# 2                          diianiitha_25
# 3                                      あ
# 4                             Bojar Laci
# 5                          Forever EXO^^
# 6                            FatimaGrace
# 7                                  ㅤㅤmin
# 8                       Amorphouscrystal
# 9                                 Gianna
# 10                      Gabriel Martinez
# 11                                     🥚
# 12                                   Ami
# 13                   SJMyLoveMyAngeles 💙
# 14                               Daniela
# 15                          @atinadpaner
# 16                                Geedee
# 17                    kpop store bandung
# 18                          Nurse Diaren
# 19                               Daniela
# 20                                 Borah
# 21                     ROLEPLAYER FAMILY
# 22                                 🍀 🍀 🍀
# 23                      Gabriel Martinez
# 24                      Amorphouscrystal
# 25                                    𝓔𝓶
# 26                              Ryvan_DE
# 27                                     あ
# 28                          @atinadpaner
# 29                      Gabriel Martinez
# ...                                  ...
# 100313                                加豪
# 100314                              idk♛
# 100315   ✨ metchuuu. #SpringBreeze #FACE
# 100316                             latte
# 100317                 moved to @manj00n
# 100318                               bal
# 100319                     Gabriel Núñez
# 100320                    Block B Sweden
# 100321                        Ncussss  ♣
# 100322                         nazuratul
# 100323                             latte
# 100324                         hasti  🇮🇷
# 100325                             Blank
# 100326                         hasti  🇮🇷
# 100327                               bon
# 100328                               Kei
# 100329                              どりまめ
# 100330                    Yang Mi Matoki
# 100331                         hasti  🇮🇷
# 100332                         hasti  🇮🇷
# 100333                          Naddy  💘
# 100334                               ㅁ ㅏ
# 100335                         hasti  🇮🇷
# 100336               galuh intan permata
# 100337                               Ros
# 100338                    료우#リプ返できないです미안
# 100339                         hasti  🇮🇷
# 100340                              Ross
# 100341                         hasti  🇮🇷
# 100342                         hasti  🇮🇷
#
#                                                      html                  id  \
# 0       <p class="TweetTextSize js-tweet-text tweet-te...  292421101257113600
# 1       <p class="TweetTextSize js-tweet-text tweet-te...  292421099516477440
# 2       <p class="TweetTextSize js-tweet-text tweet-te...  292421099109629952
# 3       <p class="TweetTextSize js-tweet-text tweet-te...  292421099067699200
# 4       <p class="TweetTextSize js-tweet-text tweet-te...  292421093841580032
# 5       <p class="TweetTextSize js-tweet-text tweet-te...  292421092130316289
# 6       <p class="TweetTextSize js-tweet-text tweet-te...  292421086849683458
# 7       <p class="TweetTextSize js-tweet-text tweet-te...  292421084651851776
# 8       <p class="TweetTextSize js-tweet-text tweet-te...  292421071720820736
# 9       <p class="TweetTextSize js-tweet-text tweet-te...  292421071519506432
# 10      <p class="TweetTextSize js-tweet-text tweet-te...  292421071297208320
# 11      <p class="TweetTextSize js-tweet-text tweet-te...  292421070034710528
# 12      <p class="TweetTextSize js-tweet-text tweet-te...  292421064720515072
# 13      <p class="TweetTextSize js-tweet-text tweet-te...  292421058550722561
# 14      <p class="TweetTextSize js-tweet-text tweet-te...  292421052636753920
# 15      <p class="TweetTextSize js-tweet-text tweet-te...  292421049130303489
# 16      <p class="TweetTextSize js-tweet-text tweet-te...  292421041031114753
# 17      <p class="TweetTextSize js-tweet-text tweet-te...  292421030826348544
# 18      <p class="TweetTextSize js-tweet-text tweet-te...  292421019623378944
# 19      <p class="TweetTextSize js-tweet-text tweet-te...  292421012228825089
# 20      <p class="TweetTextSize js-tweet-text tweet-te...  292421007946416128
# 21      <p class="TweetTextSize js-tweet-text tweet-te...  292421001705295872
# 22      <p class="TweetTextSize js-tweet-text tweet-te...  292421001134874624
# 23      <p class="TweetTextSize js-tweet-text tweet-te...  292420996600848384
# 24      <p class="TweetTextSize js-tweet-text tweet-te...  292420995334156290
# 25      <p class="TweetTextSize js-tweet-text tweet-te...  292420994587561986
# 26      <p class="TweetTextSize js-tweet-text tweet-te...  292420991475408896
# 27      <p class="TweetTextSize js-tweet-text tweet-te...  292420989248221184
# 28      <p class="TweetTextSize js-tweet-text tweet-te...  292420976531083264
# 29      <p class="TweetTextSize js-tweet-text tweet-te...  292420974035476482
# ...                                                   ...                 ...
# 100313  <p class="TweetTextSize js-tweet-text tweet-te...  397748360515309568
# 100314  <p class="TweetTextSize js-tweet-text tweet-te...  397748352818761729
# 100315  <p class="TweetTextSize js-tweet-text tweet-te...  397748351673704448
# 100316  <p class="TweetTextSize js-tweet-text tweet-te...  397748333760225280
# 100317  <p class="TweetTextSize js-tweet-text tweet-te...  397748306912104450
# 100318  <p class="TweetTextSize js-tweet-text tweet-te...  397748306488467456
# 100319  <p class="TweetTextSize js-tweet-text tweet-te...  397748291569340416
# 100320  <p class="TweetTextSize js-tweet-text tweet-te...  397748286041243648
# 100321  <p class="TweetTextSize js-tweet-text tweet-te...  397748274196537344
# 100322  <p class="TweetTextSize js-tweet-text tweet-te...  397748267791839232
# 100323  <p class="TweetTextSize js-tweet-text tweet-te...  397748263174287361
# 100324  <p class="TweetTextSize js-tweet-text tweet-te...  397748208140439552
# 100325  <p class="TweetTextSize js-tweet-text tweet-te...  397748206517248001
# 100326  <p class="TweetTextSize js-tweet-text tweet-te...  397748193510715392
# 100327  <p class="TweetTextSize js-tweet-text tweet-te...  397748185784799232
# 100328  <p class="TweetTextSize js-tweet-text tweet-te...  397748182559363073
# 100329  <p class="TweetTextSize js-tweet-text tweet-te...  397748180789366784
# 100330  <p class="TweetTextSize js-tweet-text tweet-te...  397748177673412608
# 100331  <p class="TweetTextSize js-tweet-text tweet-te...  397748176989323264
# 100332  <p class="TweetTextSize js-tweet-text tweet-te...  397748161441062912
# 100333  <p class="TweetTextSize js-tweet-text tweet-te...  397748160153399296
# 100334  <p class="TweetTextSize js-tweet-text tweet-te...  397748154436562944
# 100335  <p class="TweetTextSize js-tweet-text tweet-te...  397748141446819840
# 100336  <p class="TweetTextSize js-tweet-text tweet-te...  397748126787719168
# 100337  <p class="TweetTextSize js-tweet-text tweet-te...  397748125395595264
# 100338  <p class="TweetTextSize js-tweet-text tweet-te...  397748123897843712
# 100339  <p class="TweetTextSize js-tweet-text tweet-te...  397748123025408000
# 100340  <p class="TweetTextSize js-tweet-text tweet-te...  397748121129590785
# 100341  <p class="TweetTextSize js-tweet-text tweet-te...  397748109523943424
# 100342  <p class="TweetTextSize js-tweet-text tweet-te...  397748092851585025
#
#         like  replies  retweets  \
# 0          0        0         0
# 1          0        0         0
# 2          1        0         0
# 3          0        0         0
# 4          0        0         1
# 5          0        0         0
# 6          0        0         0
# 7          0        0         0
# 8          0        0         0
# 9          0        0         0
# 10         0        0         0
# 11         0        0         0
# 12         0        0         0
# 13         0        0         0
# 14         0        0         0
# 15         0        0         0
# 16         0        0         0
# 17         0        0         1
# 18         0        1         0
# 19         0        0         0
# 20         0        0         0
# 21         0        0         1
# 22         0        0         0
# 23         0        0         0
# 24         0        0         0
# 25         0        0         0
# 26         0        0         0
# 27         0        0         0
# 28         0        0         0
# 29         0        0         0
# ...      ...      ...       ...
# 100313     0        0         0
# 100314     0        0         0
# 100315     0        0         0
# 100316     0        0         0
# 100317     0        0         0
# 100318     0        0         3
# 100319     0        0         0
# 100320     0        0         0
# 100321     0        0         0
# 100322     0        0         0
# 100323     0        0         0
# 100324     0        0         0
# 100325     0        0         0
# 100326     0        0         0
# 100327     0        0         1
# 100328     0        0         0
# 100329     0        0         0
# 100330     0        0         0
# 100331     0        0         0
# 100332     0        0         0
# 100333     3        0         7
# 100334     0        0         0
# 100335     0        0         0
# 100336     0        0         1
# 100337     0        0         0
# 100338     0        0         0
# 100339     0        0         0
# 100340     0        0         1
# 100341     0        0         0
# 100342     0        0         0
#
#                                                      text  \
# 0       *cries* pray pray pray. I LOVE KPOP @seoulfm #...
# 1       I wanna go to KPOP Concert Dream tonight but I...
# 2                             @elmundoalreves7 kpop Exo m
# 3               I love Kpop #seoulfm #dkfc @seoulfm\n\n\n
# 4       Listening to some kpop. Missed you :( Getting ...
# 5           I Love KPOP @seoulfm! #seoulfm #dkfc jsvidhwi
# 6       I LOVE KPOP  @seoulfm #seoulfm #dkfc  waaaaaaa...
# 7       @seoulfm #dkfc #seoulfm! I Love KPOP .. Plss ?...
# 8       I LOVE KPOP @seoulfm #seoulfm #dkfc THEY ARE W...
# 9       I Love KPOP! Lemme watch the #DKFC. @seoulfm #...
# 10      I Love KPOP <3 @seoulfm #seoulfm #dkfc :)) 5 *...
# 11        I Love KPOP @seoulfm #seoulfm #dkfc ~~FANBOY 10
# 12      ユナ。RT @hoot_009: 少女時代 「DREAM KPOP Fantasy Conc...
# 13      #MaratonTelehit @tvtelehit @Natalia_Tellez #kp...
# 14               I Love KPOP @seoulfm! #seoulfm #dkfc 125
# 15      I'VE BEEN WAITING FOR MY 9 ANGELS IN TOO MANY ...
# 16      I LOVE KPOP @seoulfm! #seoulfm #dkfc I gained ...
# 17      @SHINeeWorld_Ina [OPEN PO]PAKET MUBANK"SHINEE"...
# 18          2 ung entry ng I Love KPOP sa PH trend hahaha
# 19               I Love KPOP @seoulfm! #seoulfm #dkfc 124
# 20      @VIP4Daesung @Starr_Kpop lucky ducky~~ whatcha...
# 21      @jiyoungkang94 [HELP RT] agency khusus KPOP, T...
# 22      banten channel kl gasalah, acara kpop gt :O RT...
# 23           I Love KPOP <3 @seoulfm #seoulfm #dkfc :)) 4
# 24      I'm listening @seoulfm ! #kpop #seoulfm #dkfc ...
# 25                   I LOVE KPOP. @seoulfm!#seoulfm #DKFC
# 26      WE ARE STILL HOPING.... Sana mapili din kami.....
# 27      I love Kpop #seoulfm #dkfc @seoulfm\n nothing'...
# 28      I'VE BEEN WAITING FOR MY 9 ANGELS IN TOO MANY ...
# 29           I Love KPOP <3 @seoulfm #seoulfm #dkfc :)) 3
# ...                                                   ...
# 100313  Because honestly 불러 is one of my favourite kpo...
# 100314  RT "@Isna_Clouds: NANGIS, MERINDING :") RT @ko...
# 100315  @ndest_desty Hai,mau belanja murah kualitas bg...
# 100316  "911, what's your emergency?" - kpop-confessio...
# 100317  @the_kpop_freak @itsardaeee_ i thought beast d...
# 100318  Hi fashion lovers and kpoppers.Follow instasho...
# 100319  #Happy8thAnniversarySuperjunior  El mejor grup...
# 100320  [PERFORMANCE] 131105 Simply Kpop Block B - Ver...
# 100321  "@korean_kpop: Kiseop UKISS ngucapin selamat u...
# 100322  Aq tau sape??hehe "@tehanism: Haih kenapa lah ...
# 100323  Listening kpop in the car with your family. - ...
# 100324  @HeeZZinPang #Happy8thAnniversarySuperJuniorwe...
# 100325  tbh other than kpop artistes, ive never even f...
# 100326  @AllRiseSilver #Happy8thAnniversarySuperJunior...
# 100327  it's impossible to me to forget Suju. bc of Su...
# 100328                                 しかしj&kpopはこの限りではない
# 100329  @kpop_sukiyanen_ \n実はわたしも分からなくてww\nもう一度マイドル復習するわ！
# 100330  GOOD MORNING #tuesday #baby #kpop #mybiases #m...
# 100331  @special1004 #Happy8thAnniversarySuperJuniorwe...
# 100332  @ShinsFriends #Happy8thAnniversarySuperJuniorw...
# 100333  OMG MATHS IS KPOP"@taeyangxxi: 2NE1 MATH https...
# 100334                                        TL幸せだぁぁあ♪♪♪
# 100335  @ryeong9 #Happy8thAnniversarySuperJuniorwe Bes...
# 100336  RT @korean_kpop: #Happy8thAnniversarySuperjuni...
# 100337  RT @adel861015: Proud to be ELF!!! "@korean_kp...
# 100338  #Happy8thAnniversarySuperJunior\n#Happy8thAnni...
# 100339  @Himsenkangin #Happy8thAnniversarySuperJuniorw...
# 100340  And #Happy8thAnniversarySuperJunior my first f...
# 100341  @siwon407 #Happy8thAnniversarySuperJuniorwe Be...
# 100342  @donghae861015 #Happy8thAnniversarySuperJunior...
#
#                   timestamp                                         url  \
# 0       2013-01-18T23:59:58        /dpflzk002/status/292421101257113600
# 1       2013-01-18T23:59:57        /ohohaliii/status/292421099516477440
# 2       2013-01-18T23:59:57    /diianiitha_25/status/292421099109629952
# 3       2013-01-18T23:59:57          /Sxgxrxx/status/292421099067699200
# 4       2013-01-18T23:59:56        /stAMyXOXO/status/292421093841580032
# 5       2013-01-18T23:59:55        /klaryle03/status/292421092130316289
# 6       2013-01-18T23:59:54       /YongFatima/status/292421086849683458
# 7       2013-01-18T23:59:54       /winksyeoja/status/292421084651851776
# 8       2013-01-18T23:59:51     /cjdelacruz26/status/292421071720820736
# 9       2013-01-18T23:59:51     /asdfgiannaxx/status/292421071519506432
# 10      2013-01-18T23:59:50    /mrgabmartinez/status/292421071297208320
# 11      2013-01-18T23:59:50       /baejinpink/status/292421070034710528
# 12      2013-01-18T23:59:49         /amiy_530/status/292421064720515072
# 13      2013-01-18T23:59:47         /julisp89/status/292421058550722561
# 14      2013-01-18T23:59:46   /alltimepramore/status/292421052636753920
# 15      2013-01-18T23:59:45    /DanitaPLovers/status/292421049130303489
# 16      2013-01-18T23:59:43       /geeslurpee/status/292421041031114753
# 17      2013-01-18T23:59:41      /KPop_Stores/status/292421030826348544
# 18      2013-01-18T23:59:38         /Diaren91/status/292421019623378944
# 19      2013-01-18T23:59:36   /alltimepramore/status/292421012228825089
# 20      2013-01-18T23:59:35   /Snapshot_Color/status/292421007946416128
# 21      2013-01-18T23:59:34  /Roleplayer_Fams/status/292421001705295872
# 22      2013-01-18T23:59:34       /amyhumaira/status/292421001134874624
# 23      2013-01-18T23:59:33    /mrgabmartinez/status/292420996600848384
# 24      2013-01-18T23:59:32     /cjdelacruz26/status/292420995334156290
# 25      2013-01-18T23:59:32   /maritaarellxno/status/292420994587561986
# 26      2013-01-18T23:59:31      /PhayLee1004/status/292420991475408896
# 27      2013-01-18T23:59:31          /Sxgxrxx/status/292420989248221184
# 28      2013-01-18T23:59:28    /DanitaPLovers/status/292420976531083264
# 29      2013-01-18T23:59:27    /mrgabmartinez/status/292420974035476482
# ...                     ...                                         ...
# 100313  2013-11-05T15:32:53           /_iRYAN/status/397748360515309568
# 100314  2013-11-05T15:32:51        /dindaazrf/status/397748352818761729
# 100315  2013-11-05T15:32:51  /annyunghasenika/status/397748351673704448
# 100316  2013-11-05T15:32:47          /onlatte/status/397748333760225280
# 100317  2013-11-05T15:32:40         /zozoeyey/status/397748306912104450
# 100318  2013-11-05T15:32:40       /qtpieyehet/status/397748306488467456
# 100319  2013-11-05T15:32:37      /GabrielNez2/status/397748291569340416
# 100320  2013-11-05T15:32:35    /blockb_sweden/status/397748286041243648
# 100321  2013-11-05T15:32:33    /Nurulchustiah/status/397748274196537344
# 100322  2013-11-05T15:32:31        /unanana97/status/397748267791839232
# 100323  2013-11-05T15:32:30          /onlatte/status/397748263174287361
# 100324  2013-11-05T15:32:17        /Hasti_e65/status/397748208140439552
# 100325  2013-11-05T15:32:16  /divorceforcezxc/status/397748206517248001
# 100326  2013-11-05T15:32:13        /Hasti_e65/status/397748193510715392
# 100327  2013-11-05T15:32:11       /baekbbyhun/status/397748185784799232
# 100328  2013-11-05T15:32:11        /KeI_0814_/status/397748182559363073
# 100329  2013-11-05T15:32:10     /dori_vixxleo/status/397748180789366784
# 100330  2013-11-05T15:32:10      /Yang_Matoki/status/397748177673412608
# 100331  2013-11-05T15:32:09        /Hasti_e65/status/397748176989323264
# 100332  2013-11-05T15:32:06        /Hasti_e65/status/397748161441062912
# 100333  2013-11-05T15:32:05    /seunghyun_kun/status/397748160153399296
# 100334  2013-11-05T15:32:04         /kpop_96_/status/397748154436562944
# 100335  2013-11-05T15:32:01        /Hasti_e65/status/397748141446819840
# 100336  2013-11-05T15:31:57      /galuhintann/status/397748126787719168
# 100337  2013-11-05T15:31:57         /ross_par/status/397748125395595264
# 100338  2013-11-05T15:31:57    /kpop_bknb_uum/status/397748123897843712
# 100339  2013-11-05T15:31:56        /Hasti_e65/status/397748123025408000
# 100340  2013-11-05T15:31:56        /yozzroses/status/397748121129590785
# 100341  2013-11-05T15:31:53        /Hasti_e65/status/397748109523943424
# 100342  2013-11-05T15:31:49        /Hasti_e65/status/397748092851585025
#
#                    user
# 0             dpflzk002
# 1             ohohaliii
# 2         diianiitha_25
# 3               Sxgxrxx
# 4             stAMyXOXO
# 5             klaryle03
# 6            YongFatima
# 7            winksyeoja
# 8          cjdelacruz26
# 9          asdfgiannaxx
# 10        mrgabmartinez
# 11           baejinpink
# 12             amiy_530
# 13             julisp89
# 14       alltimepramore
# 15        DanitaPLovers
# 16           geeslurpee
# 17          KPop_Stores
# 18             Diaren91
# 19       alltimepramore
# 20       Snapshot_Color
# 21      Roleplayer_Fams
# 22           amyhumaira
# 23        mrgabmartinez
# 24         cjdelacruz26
# 25       maritaarellxno
# 26          PhayLee1004
# 27              Sxgxrxx
# 28        DanitaPLovers
# 29        mrgabmartinez
# ...                 ...
# 100313           _iRYAN
# 100314        dindaazrf
# 100315  annyunghasenika
# 100316          onlatte
# 100317         zozoeyey
# 100318       qtpieyehet
# 100319      GabrielNez2
# 100320    blockb_sweden
# 100321    Nurulchustiah
# 100322        unanana97
# 100323          onlatte
# 100324        Hasti_e65
# 100325  divorceforcezxc
# 100326        Hasti_e65
# 100327       baekbbyhun
# 100328        KeI_0814_
# 100329     dori_vixxleo
# 100330      Yang_Matoki
# 100331        Hasti_e65
# 100332        Hasti_e65
# 100333    seunghyun_kun
# 100334         kpop_96_
# 100335        Hasti_e65
# 100336      galuhintann
# 100337         ross_par
# 100338    kpop_bknb_uum
# 100339        Hasti_e65
# 100340        yozzroses
# 100341        Hasti_e65
# 100342        Hasti_e65
#
# [100343 rows x 10 columns]

# %%
import nltk

# %%
tokens = nltk.word_tokenize(df['text'][0]) # 첫번째 행의 뉴스 내용에서 토큰 추출
tokens
# Out:
# ['*cries*',
#  'pray',
#  'pray',
#  'pray',
#  '.',
#  'I',
#  'LOVE',
#  'KPOP',
#  '@',
#  'seoulfm',
#  '#',
#  'seoulfm',
#  '#',
#  'dkfc']

# %%
tokens = [token.lower() for token in tokens if len(token) > 1]
tokens
# Out:
# ['*cries*',
#  'pray',
#  'pray',
#  'pray',
#  'love',
#  'kpop',
#  'seoulfm',
#  'seoulfm',
#  'dkfc']

# %%
tokens_bigram = nltk.bigrams(tokens)
for token in tokens_bigram :
    print(token)
# Out:
# ('*cries*', 'pray')
# ('pray', 'pray')
# ('pray', 'pray')
# ('pray', 'love')
# ('love', 'kpop')
# ('kpop', 'seoulfm')
# ('seoulfm', 'seoulfm')
# ('seoulfm', 'dkfc')

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
tokens_clean = [token for token in tokens if not token in stop_words]
tokens_clean
# Out:
# ['*cries*',
#  'pray',
#  'pray',
#  'pray',
#  'love',
#  'kpop',
#  'seoulfm',
#  'seoulfm',
#  'dkfc']

# %%
tokens_tagged = nltk.pos_tag(tokens_clean)
print(tokens_tagged)
# Out:
# [('*cries*', 'JJ'), ('pray', 'NN'), ('pray', 'NN'), ('pray', 'NN'), ('love', 'VB'), ('kpop', 'NN'), ('seoulfm', 'NN'), ('seoulfm', 'NN'), ('dkfc', 'NN')]

# %%
tokens_noun = [word for word, pos in tokens_tagged if pos in ['NN', 'NNP']]
print(tokens_noun)
# Out:
# ['pray', 'pray', 'pray', 'kpop', 'seoulfm', 'seoulfm', 'dkfc']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
stopwords = set(STOPWORDS)
wc = WordCloud(background_color="black", max_font_size=100, max_words=50, stopwords=stopwords)

# %%
text_data = df['text'].str.cat(sep=', ')
wordcloud = wc.generate(text_data)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

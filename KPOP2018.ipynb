# %%
import json
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('KPOP2018.csv', encoding = 'UTF8')

# %%
df
# Out:
#                                        fullname  \
# 0                              HYPER COUTURE NY
# 1                                 DMUMT || SHAD
# 2      ~ АгреСсивНо-ПаСсивНый ~  (∿°○°)∿ ︵ ǝʌol
# 3                       KPOP POLLING - PICK ONE
# 4                                  รับกดบัตรคอน
# 5                                        trivia
# 6                             Hope World   رزان
# 7                               Alexander / 알렉스
# 8                              The Kpop Compass
# 9                                      ◄✪CKCS✪►
# 10                               *_*Jeon Lin*_*
# 11                                  k_superstar
# 12                                    kyungsᵘʷᵘ
# 13                                DMUMT || SHAD
# 14                     missing joon hours: open
# 15                                       Samira
# 16                            Asawa Ni Chanyeol
# 17                            Kpopers Indonesia
# 18                   📌OPEN SHARING SG WANNA ONE
# 19                                   ぷいん 無言お迎え中
# 20                               kpop aesthetic
# 21                                        aleah
# 22                       ❀EXO❀ ᴱᴹᴾᴱᴿᴼᴿˢ ᴼᶠ ᴷᴾᴼᴾ
# 23                    K-POP!!おすすめ動画＆ビートエボYGプレイ垢
# 24                            Hope World   رزان
# 25                            the changbin anti
# 26                                         ihmk
# 27               K O O K I E - janae is busy :(
# 28                            Hope World   رزان
# 29           Ceanne Yook #SIX_CASH #HOUR_MOMENT
# ...                                         ...
# 95256                                     Kayla
# 95257                                     ennnn
# 95258                             Lunar Jack  🌙
# 95259                           manu loves rafa
# 95260                                   943_662
# 95261                     Freckles and moles  🙊
# 95262                           Erza Lucy Taiga
# 95263                                      jhay
# 95264                           Okie Tokie Shop
# 95265          🍁Seoked In The Heart By Hoseok 🍁
# 95266                                    ʝoαnα.
# 95267                       K-POPグッズ(プロフ見てください)
# 95268                                  Ssofwanz
# 95269                                     lee 🌙
# 95270                                 Dena_kpop
# 95271                                ExcuseMe 🐥
# 95272                                      Nebu
# 95273                              aquamarine 🌹
# 95274                                         🌗
# 95275                             What The Kpop
# 95276     winner jinwoo loops - blackpink  lisa
# 95277                                      lino
# 95278                                       yas
# 95279                              letica souza
# 95280                                       caz
# 95281                              hatsune miku
# 95282                                     freya
# 95283                                       leo
# 95284                                    Meoww~
# 95285                             BTS ARMY  ⭐️'
#
#                                                     html  likes  replies  \
# 0      <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 1      <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 2      <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 3      <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 4      <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 5      <p class="TweetTextSize js-tweet-text tweet-te...      1        0
# 6      <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 7      <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 8      <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 9      <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 10     <p class="TweetTextSize js-tweet-text tweet-te...      1        0
# 11     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 12     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 13     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 14     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 15     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 16     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 17     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 18     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 19     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 20     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 21     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 22     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 23     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 24     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 25     <p class="TweetTextSize js-tweet-text tweet-te...      1        0
# 26     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 27     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 28     <p class="TweetTextSize js-tweet-text tweet-te...      0        3
# 29     <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# ...                                                  ...    ...      ...
# 95256  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 95257  <p class="TweetTextSize js-tweet-text tweet-te...     47        1
# 95258  <p class="TweetTextSize js-tweet-text tweet-te...      3        0
# 95259  <p class="TweetTextSize js-tweet-text tweet-te...      1        1
# 95260  <p class="TweetTextSize js-tweet-text tweet-te...      1        1
# 95261  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 95262  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 95263  <p class="TweetTextSize js-tweet-text tweet-te...      2        0
# 95264  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 95265  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 95266  <p class="TweetTextSize js-tweet-text tweet-te...      1        0
# 95267  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 95268  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 95269  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 95270  <p class="TweetTextSize js-tweet-text tweet-te...      0        1
# 95271  <p class="TweetTextSize js-tweet-text tweet-te...      5        3
# 95272  <p class="TweetTextSize js-tweet-text tweet-te...      6        0
# 95273  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 95274  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 95275  <p class="TweetTextSize js-tweet-text tweet-te...     11        1
# 95276  <p class="TweetTextSize js-tweet-text tweet-te...      0        4
# 95277  <p class="TweetTextSize js-tweet-text tweet-te...     13        0
# 95278  <p class="TweetTextSize js-tweet-text tweet-te...      0        1
# 95279  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 95280  <p class="TweetTextSize js-tweet-text tweet-te...      1        1
# 95281  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 95282  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 95283  <p class="TweetTextSize js-tweet-text tweet-te...      1        0
# 95284  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
# 95285  <p class="TweetTextSize js-tweet-text tweet-te...      0        0
#
#        retweets                                               text  \
# 0             0  HARRIS TWEED x HYPER\nstlike_hyper \n#fashion ...
# 1             0  من وين جت الخماسيه المليونيه اجل اذا كانو محتل...
# 2             0  9\nЯ пассивный пассив. Но может ты думаешь ина...
# 3             0                       Super Junior song you like :
# 4             0  รีวิวกดบัตร #NESTIVAL2018 วันนี้ค่ะ\nลูกค้าได้...
# 5             0  günaydın sabah annemle arabayla çarşıya giderk...
# 6             0  ما تفرق ع اساس فرقة الحناجر \nالذهبية اسفة بس ...
# 7             0  굿모닝   #milano #thankyou #heartbeats #남매 #milan...
# 8             0  Very toxic day at work.. Just got home..  I wi...
# 9             0  Pre-order KPOP Album : BTS , Wanna One , GOT7 ...
# 10            0                                           Спасибо
# 11            0                                            #lonely
# 12            0  Voice Teacher Reacts to Kpop Idols WORST vs. B...
# 13            0                         pic.twitter.com/EkmhLf5d24
# 14            0  @BTStrading @PhotocardTrade @tradkpop @kpop_tr...
# 15            0  So excited just dance 2019 is 40% off on the p...
# 16            0  BLACKPINK'S SONGS GROUP CHAT\n\nBOOMBAYAH: I'm...
# 17            0  [EXO Facts] Tao has a full name Huang Zi Tao. ...
# 18            0  Picture diary masih avail^^https://twitter.com...
# 19            0                                             ジンくんロス
# 20            0  kpopmemesandchickennuggets:\n\n(( fried dumpli...
# 21            0  Here in PH, if u'r a kpop fan, hindi mo mahal ...
# 22            0                         pic.twitter.com/3Gsp01lNh7
# 23            0                                            お疲れ様ですー
# 24            0  يا اختي نشز كم ثانية و ذا شي طبيعي في الفنان \...
# 25            0  can’t wait to explain to my parents why i’m be...
# 26            0  kau join kpop merch contest d ig tpi lupa yg a...
# 27            0  I will settle this for y”all Blackpink queens ...
# 28            0  طيب اكسو كانت محتلة الاسواق \nدحين بما اني اتا...
# 29            0  I FEEL SO GREATFUL THAT THE MOMENT I BECAME A ...
# ...         ...                                                ...
# 95256         0  Does anyone happen to have a gif of Yanan’s “m...
# 95257        35  hey new kpop stans here’s what you missed  pic...
# 95258         0  Пьяный контент Бантан [3] \n\n\n#BTS #ARMY #kp...
# 95259         0  Oia como tu fala das minhas filhas hein '-' es...
# 95260         0                                       يصير نتقسمه
# 95261         0  BEST KPOP VIDEO http://www.trendingmusicawards...
# 95262         0  If u lyk anime and kpop. Follow me, @erzalucyx...
# 95263         0  I want ppl to realized that kpop is not a tras...
# 95264         0  Okie tokie hadir! Fashion korea, kpop stuff, s...
# 95265         0  Either of these two is good~ pic.twitter.com/j...
# 95266         1  when louis' album comes out its over for yall ...
# 95267         0  【拡散希望】\nユン・シユン チラシ シール 400円(+送料)でお譲りします。\nApin...
# 95268         0  BEST KPOP FEMALE GROUP http://www.trendingmusi...
# 95269         0  kpop unsolved: how can lee jeno have that kind...
# 95270         0                                      هذا مالتي وبس
# 95271         4  Kpop and fandom ones are where we need to vote...
# 95272         0                   Maybe they think kpop is a genre
# 95273         0                           Any jbj photocard please
# 95274         0  I just wanna apologize to anybody who followed...
# 95275         4  It's #NationalHighFiveDay! If you could do a h...
# 95276         0  it means kpop will be even faker so numbers of...
# 95277         1  Lol it was for the 2nd generation of kpop. Its...
# 95278         1  virou otaku e voltou pro kpop por causa da nan...
# 95279         0  Gostar de kpop( sendo mais velha) é ver pessoa...
# 95280         0  It’s weird to see how much the kpop sound has ...
# 95281         0  AHAHAHAH I CANT BELIEVE I GOT MY BEST FRIEND A...
# 95282         0  siapa lagi ya. ANAK RP_KPOP_IDOLS esp heechul,...
# 95283         0  sad boy edgy boy garota padrao estereotipo cor...
# 95284         0                                            Hoping
# 95285         0  - \nKPOP REVOLUTION: BTS\n#PremiosMTVMiaw #MTV...
#
#                  timestamp                                          url  \
# 0      2018-11-24T07:54:06  /hypercouture_ny/status/1066238515808296960
# 1      2018-11-24T07:54:00         /ShadExol/status/1066238491972042754
# 2      2018-11-24T07:54:00  /saharnaya_zhopa/status/1066238491019931648
# 3      2018-11-24T07:53:58     /polls_kpoppp/status/1066238481414778880
# 4      2018-11-24T07:53:57         /Fnz_Kpop/status/1066238476125761538
# 5      2018-11-24T07:53:55      /yoonkookart/status/1066238469712822272
# 6      2018-11-24T07:53:53      /soperlovess/status/1066238459214553088
# 7      2018-11-24T07:53:51    /alexxpanorama/status/1066238450536468481
# 8      2018-11-24T07:53:48   /TheKpopCompass/status/1066238441145348096
# 9      2018-11-24T07:53:48           /fk_fun/status/1066238438406406144
# 10     2018-11-24T07:53:47       /kpop07_lin/status/1066238434833063937
# 11     2018-11-24T07:53:46      /luv_kpop777/status/1066238432123518982
# 12     2018-11-24T07:53:40         /chanplum/status/1066238406349352960
# 13     2018-11-24T07:53:35         /ShadExol/status/1066238383578583040
# 14     2018-11-24T07:53:34         /silkyhob/status/1066238380680208384
# 15     2018-11-24T07:53:32       /samira1130/status/1066238371209580544
# 16     2018-11-24T07:53:32         /khane_22/status/1066238370911678465
# 17     2018-11-24T07:53:30  /worldKpop___ina/status/1066238366230863873
# 18     2018-11-24T07:53:28    /Terminal_kpop/status/1066238356239970304
# 19     2018-11-24T07:53:27        /puin_kpop/status/1066238350737125376
# 20     2018-11-24T07:53:26       /ramyeonjpg/status/1066238347914420224
# 21     2018-11-24T07:53:26    /nimbustheonce/status/1066238346555322368
# 22     2018-11-24T07:53:16   /UnicornRider10/status/1066238304226557952
# 23     2018-11-24T07:53:14     /KPOP84748969/status/1066238296500531200
# 24     2018-11-24T07:53:12      /soperlovess/status/1066238287264784384
# 25     2018-11-24T07:53:07          /chvnful/status/1066238265970368512
# 26     2018-11-24T07:53:05    /antares______/status/1066238258034565120
# 27     2018-11-24T07:53:01       /JanaeMeade/status/1066238242075410432
# 28     2018-11-24T07:52:54      /soperlovess/status/1066238212992131072
# 29     2018-11-24T07:52:53          /SJ6_NNN/status/1066238211234693120
# ...                    ...                                          ...
# 95256  2018-04-19T17:46:57     /kaymarie_kpop/status/987024768997232642
# 95257  2018-04-19T17:46:55         /ainzainrn/status/987024762110033920
# 95258  2018-04-19T17:46:55        /LunarJack1/status/987024758398226432
# 95259  2018-04-19T17:46:52    /SideToMartinez/status/987024746729623552
# 95260  2018-04-19T17:46:51    /youmylove_2017/status/987024744099794944
# 95261  2018-04-19T17:46:44   /ultra_violet_mx/status/987024714269937664
# 95262  2018-04-19T17:46:43    /erzalucyxnatsu/status/987024711572832256
# 95263  2018-04-19T17:46:39         /minxyngii/status/987024694820782080
# 95264  2018-04-19T17:46:35        /Okie_Tokie/status/987024675933798400
# 95265  2018-04-19T17:46:33      /SpacePrince8/status/987024668170174469
# 95266  2018-04-19T17:46:32        /cagethelwt/status/987024665397874688
# 95267  2018-04-19T17:46:32           /kpop_tt/status/987024662914744321
# 95268  2018-04-19T17:46:30         /Ssofwanz1/status/987024656778477568
# 95269  2018-04-19T17:46:22      /affectjunate/status/987024623622537216
# 95270  2018-04-19T17:46:22         /dena_kpop/status/987024620216872960
# 95271  2018-04-19T17:46:22    /Excusemechimmy/status/987024619671613440
# 95272  2018-04-19T17:46:16          /NNeboola/status/987024595667640320
# 95273  2018-04-19T17:46:09     /joyful787_ksg/status/987024565489537024
# 95274  2018-04-19T17:46:03         /sapphorre/status/987024541582069761
# 95275  2018-04-19T17:46:00      /whatthekpop1/status/987024527430488064
# 95276  2018-04-19T17:45:54          /kokohoho/status/987024504017903617
# 95277  2018-04-19T17:45:53          /jypskids/status/987024501966684161
# 95278  2018-04-19T17:45:42         /yasminsyj/status/987024454277529600
# 95279  2018-04-19T17:45:39       /SouzaLetica/status/987024442663538688
# 95280  2018-04-19T17:45:36       /chanbaekiki/status/987024426716876800
# 95281  2018-04-19T17:45:31         /yoonbabyy/status/987024408572080129
# 95282  2018-04-19T17:45:30       /ichijuuichi/status/987024403274678272
# 95283  2018-04-19T17:45:30          /leozita_/status/987024402775724032
# 95284  2018-04-19T17:45:25      /aliyah_chiii/status/987024383871873024
# 95285  2018-04-19T17:45:24         /M_BTSArmy/status/987024377685381121
#
#                   user
# 0      hypercouture_ny
# 1             ShadExol
# 2      saharnaya_zhopa
# 3         polls_kpoppp
# 4             Fnz_Kpop
# 5          yoonkookart
# 6          soperlovess
# 7        alexxpanorama
# 8       TheKpopCompass
# 9               fk_fun
# 10          kpop07_lin
# 11         luv_kpop777
# 12            chanplum
# 13            ShadExol
# 14            silkyhob
# 15          samira1130
# 16            khane_22
# 17     worldKpop___ina
# 18       Terminal_kpop
# 19           puin_kpop
# 20          ramyeonjpg
# 21       nimbustheonce
# 22      UnicornRider10
# 23        KPOP84748969
# 24         soperlovess
# 25             chvnful
# 26       antares______
# 27          JanaeMeade
# 28         soperlovess
# 29             SJ6_NNN
# ...                ...
# 95256    kaymarie_kpop
# 95257        ainzainrn
# 95258       LunarJack1
# 95259   SideToMartinez
# 95260   youmylove_2017
# 95261  ultra_violet_mx
# 95262   erzalucyxnatsu
# 95263        minxyngii
# 95264       Okie_Tokie
# 95265     SpacePrince8
# 95266       cagethelwt
# 95267          kpop_tt
# 95268        Ssofwanz1
# 95269     affectjunate
# 95270        dena_kpop
# 95271   Excusemechimmy
# 95272         NNeboola
# 95273    joyful787_ksg
# 95274        sapphorre
# 95275     whatthekpop1
# 95276         kokohoho
# 95277         jypskids
# 95278        yasminsyj
# 95279      SouzaLetica
# 95280      chanbaekiki
# 95281        yoonbabyy
# 95282      ichijuuichi
# 95283         leozita_
# 95284     aliyah_chiii
# 95285        M_BTSArmy
#
# [95286 rows x 9 columns]

# %%
import nltk

# %%
tokens = nltk.word_tokenize(df['text'][0]) # 첫번째 행의 뉴스 내용에서 토큰 추출
tokens
# Out:
# ['HARRIS',
#  'TWEED',
#  'x',
#  'HYPER',
#  'stlike_hyper',
#  '#',
#  'fashion',
#  '#',
#  'hoodie',
#  '#',
#  'denim',
#  '#',
#  'harristweed',
#  '#',
#  'downjacket',
#  '#',
#  'vetements',
#  '#',
#  'supreme',
#  '#',
#  'streetfashion',
#  '#',
#  'koreafashion',
#  '#',
#  'skater',
#  '#',
#  'kpop',
#  '#',
#  'bts',
#  '#',
#  'gdragon',
#  '#',
#  'twice',
#  '#',
#  'blackpink…',
#  'https',
#  ':',
#  '//www.instagram.com/p/Bqji_hdhp6J/',
#  '?',
#  'utm_source=ig_twitter_share',
#  '&',
#  'igshid=e5z5zjyj077u',
#  '…']

# %%
tokens = [token.lower() for token in tokens if len(token) > 1]
tokens
# Out:
# ['harris',
#  'tweed',
#  'hyper',
#  'stlike_hyper',
#  'fashion',
#  'hoodie',
#  'denim',
#  'harristweed',
#  'downjacket',
#  'vetements',
#  'supreme',
#  'streetfashion',
#  'koreafashion',
#  'skater',
#  'kpop',
#  'bts',
#  'gdragon',
#  'twice',
#  'blackpink…',
#  'https',
#  '//www.instagram.com/p/bqji_hdhp6j/',
#  'utm_source=ig_twitter_share',
#  'igshid=e5z5zjyj077u']

# %%
tokens_bigram = nltk.bigrams(tokens)
for token in tokens_bigram :
    print(token)
# Out:
# ('harris', 'tweed')
# ('tweed', 'hyper')
# ('hyper', 'stlike_hyper')
# ('stlike_hyper', 'fashion')
# ('fashion', 'hoodie')
# ('hoodie', 'denim')
# ('denim', 'harristweed')
# ('harristweed', 'downjacket')
# ('downjacket', 'vetements')
# ('vetements', 'supreme')
# ('supreme', 'streetfashion')
# ('streetfashion', 'koreafashion')
# ('koreafashion', 'skater')
# ('skater', 'kpop')
# ('kpop', 'bts')
# ('bts', 'gdragon')
# ('gdragon', 'twice')
# ('twice', 'blackpink…')
# ('blackpink…', 'https')
# ('https', '//www.instagram.com/p/bqji_hdhp6j/')
# ('//www.instagram.com/p/bqji_hdhp6j/', 'utm_source=ig_twitter_share')
# ('utm_source=ig_twitter_share', 'igshid=e5z5zjyj077u')

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
tokens_clean = [token for token in tokens if not token in stop_words]
tokens_clean
# Out:
# ['harris',
#  'tweed',
#  'hyper',
#  'stlike_hyper',
#  'fashion',
#  'hoodie',
#  'denim',
#  'harristweed',
#  'downjacket',
#  'vetements',
#  'supreme',
#  'streetfashion',
#  'koreafashion',
#  'skater',
#  'kpop',
#  'bts',
#  'gdragon',
#  'twice',
#  'blackpink…',
#  'https',
#  '//www.instagram.com/p/bqji_hdhp6j/',
#  'utm_source=ig_twitter_share',
#  'igshid=e5z5zjyj077u']

# %%
tokens_tagged = nltk.pos_tag(tokens_clean)
print(tokens_tagged)
# Out:
# [('harris', 'NNS'), ('tweed', 'VBP'), ('hyper', 'JJR'), ('stlike_hyper', 'JJ'), ('fashion', 'NN'), ('hoodie', 'NN'), ('denim', 'VBP'), ('harristweed', 'NN'), ('downjacket', 'NN'), ('vetements', 'NNS'), ('supreme', 'JJ'), ('streetfashion', 'NN'), ('koreafashion', 'NN'), ('skater', 'NN'), ('kpop', 'NN'), ('bts', 'NNS'), ('gdragon', 'NN'), ('twice', 'RB'), ('blackpink…', 'RB'), ('https', 'JJ'), ('//www.instagram.com/p/bqji_hdhp6j/', 'NNP'), ('utm_source=ig_twitter_share', 'NN'), ('igshid=e5z5zjyj077u', 'NN')]

# %%
tokens_noun = [word for word, pos in tokens_tagged if pos in ['NN', 'NNP']]
print(tokens_noun)
# Out:
# ['fashion', 'hoodie', 'harristweed', 'downjacket', 'streetfashion', 'koreafashion', 'skater', 'kpop', 'gdragon', '//www.instagram.com/p/bqji_hdhp6j/', 'utm_source=ig_twitter_share', 'igshid=e5z5zjyj077u']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
stopwords = set(STOPWORDS)
wc = WordCloud(background_color="red", max_font_size=100, max_words=50, stopwords=stopwords)

# %%
text_data = df['text'].str.cat(sep=', ')
wordcloud = wc.generate(text_data)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
